# %% [markdown]
# # **[필수 과제1] Series**
# > ![image.png](data:image/png;base64,...)
#
# - 시리즈 형태 문법 작성하여 값 확인 (위의 문법들)
# - 구글링 통해 문법 3개 이상 검색, 해당 문법 설명 및 코드 작성

# %%
import pandas as pd

# %%
df = pd.read_csv('gapminder.tsv', sep='\t')

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df_se1 = df['year']

# %%
df_se2 = df['lifeExp']

# %%
df_se1
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
df_se2
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: lifeExp, Length: 1704, dtype: float64

# %% [markdown]
# ### 시리즈 형태 문법 사용

# %%
df_se1.describe()
# Out:
# count    1704.00000
# mean     1979.50000
# std        17.26533
# min      1952.00000
# 25%      1965.75000
# 50%      1979.50000
# 75%      1993.25000
# max      2007.00000
# Name: year, dtype: float64

# %%
df_se1.drop_duplicates()
# Out:
# 0     1952
# 1     1957
# 2     1962
# 3     1967
# 4     1972
# 5     1977
# 6     1982
# 7     1987
# 8     1992
# 9     1997
# 10    2002
# 11    2007
# Name: year, dtype: int64

# %% [markdown]
# get_values() 대신 to_numpy() 사용 (버전 문제)

# %%
df_se1.to_numpy()
# Out:
# array([1952, 1957, 1962, ..., 1997, 2002, 2007])

# %%
df_se1.sort_values()
# Out:
# 0       1952
# 528     1952
# 540     1952
# 1656    1952
# 552     1952
#         ...
# 1127    2007
# 1139    2007
# 1151    2007
# 1175    2007
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
df_se1.to_frame()
# Out:
#       year
# 0     1952
# 1     1957
# 2     1962
# 3     1967
# 4     1972
# ...    ...
# 1699  1987
# 1700  1992
# 1701  1997
# 1702  2002
# 1703  2007
#
# [1704 rows x 1 columns]

# %%
df_se1.append(df_se2)
# Out:
# <ipython-input-22-9f10ff17ccf0>:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_se1.append(df_se2)
# 0       1952.000
# 1       1957.000
# 2       1962.000
# 3       1967.000
# 4       1972.000
#           ...
# 1699      62.351
# 1700      60.377
# 1701      46.809
# 1702      39.989
# 1703      43.487
# Length: 3408, dtype: float64

# %% [markdown]
# df_se1의 index 0-1703 + df_se2의 index 0-1703 (총 길이: 3408)

# %% [markdown]
# ### 그 외의 문법들

# %%
# value_counts() : 개수 확인
df_se1.value_counts()
# Out:
# 1952    142
# 1957    142
# 1962    142
# 1967    142
# 1972    142
# 1977    142
# 1982    142
# 1987    142
# 1992    142
# 1997    142
# 2002    142
# 2007    142
# Name: year, dtype: int64

# %%
# idxmax() : 최대값의 index 출력
df_se2.idxmax()
# Out:
# 803

# %%
# idxmin() : 최솟값의 index 출력
df_se2.idxmin()
# Out:
# 1292

# %%
# isin() : 값 존재 유무 확인
is_2007 = df_se1.isin([2007])

# %%
is_2007
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703     True
# Name: year, Length: 1704, dtype: bool

# %%
is_2007.value_counts()
# Out:
# False    1562
# True      142
# Name: year, dtype: int64

# %% [markdown]
# 'year'열에 2007값 142개 존재
